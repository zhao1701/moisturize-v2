# %%
import os
import sys
from pathlib import Path

import git
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.image as img
import matplotlib.pyplot as plt
from matplotlib import rcParams

sys.path.append(git.Repo(search_parent_directories=True).working_dir)
sns.set(context='notebook', style='whitegrid')
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = 'times new roman'

from config import TRAIN_DATA_DIR

# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img_filenames = list(TRAIN_DATA_DIR.glob('*'))
print(f'Found {len(img_filenames)} images.')
# Out:
# Found 202599 images.

# %%
random_img = np.random.choice(img_filenames)
arr = img.imread(random_img)

plt.figure(figsize=(16, 14))
plt.imshow(arr)
ax = plt.gca()
ax.axis('off')
# Out:
# (-0.5, 177.5, 217.5, -0.5)
